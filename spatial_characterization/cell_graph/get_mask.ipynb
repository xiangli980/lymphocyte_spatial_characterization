# %%
import skimage.io as skio
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from skimage import img_as_ubyte

# %%
dirs = os.listdir('/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/export/701081')
print(dirs)
# Out:
# ['Annotation (Region*) Region 1.png', 'Annotation (Region*) Image 1.png', '._Annotation (Region*) Region 1.png']

# %%
os.listdir('/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/export/701080')
# Out:
# ['Annotation (Region*) Region 1.png', '701080.png', '._701080.png']

# %%
os.listdir('/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only2')
# Out:
# []

# %%
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

# %%
from PIL import Image
Image.MAX_IMAGE_PIXELS = None
msk = skio.imread('/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/export/701080/Annotation (Region*) Region 1.png', plugin='pil')

# %%
msk.shape
# Out:
# (27682, 24677)

# %%
# copy img to a new dir using shutil
import shutil
from_dir = '/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/export/701081/Annotation (Region*) Image 1.png'
to_dir = '/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only/701081.png'
shutil.copy(from_dir, to_dir)
# Out:
# '/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only/701081.png'

# %%
plt.imshow(msk)

# %%
msk.shape
# Out:
# (25619, 22245, 3)

# %%
7834.807486631016, 25611.994652406418

# %%
# create a mask with same shape as msk
mask = np.zeros((int(msk.shape[0]/10),int(msk.shape[1]/10)), dtype=np.uint8)

# %%
# create a circle in the mask filled with white
import cv2
mask = cv2.circle(mask, (int(mask.shape[1]/5)+500, int(mask.shape[0]/5)+500), int(mask.shape[1]/5), 255, -1)

# %%
plt.imshow(mask)

# %%
skio.imsave('/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only_output/msk/701081.png', mask)

# %%
mask.shape
# Out:
# (2561, 2224)

# %%
os.listdir('./')
# Out:
# ['run_graph.py',
#  'utils.py',
#  '__pycache__',
#  'get_mask.ipynb',
#  'test_input',
#  'run_graph_mask.py',
#  'run_graph.sh',
#  'test_output',
#  'Annotation (Necrosis) Region 1.png']

# %%
msk = skio.imread('./Annotation (Tumor) Region 1.png', plugin='pil')

# %%
msk.shape
# Out:
# (3532, 2626, 3)

# %%
plt.imshow(msk)

# %%
plt.hist(msk.flatten())
# Out:
# (array([16522492.,        0.,        0.,    27814.,        0.,        0.,
#            27814.,  8261246.,    27814., 16619814.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
# turn the mask into a grey scale image using skimage
from skimage import img_as_ubyte
mask = msk<255
mask = img_as_ubyte(mask)

# %%
mask = msk<255
mask = img_as_ubyte(mask)

# %%
plt.imshow(mask)

# %%
msk = msk[:,:,0]

# %%
x0 = 207
y0 = 5.4
if msk[int(y0/10), int(x0/10)] == 255:
    print('yes')

# %%
plt.imshow(mask)

# %%
mask = mask[:,:,0]

# %%
msks = os.listdir("/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only_output2/msk")

# %%
print(msks)
# Out:
# ['700942Sample.png', '._700942Sample.png']

# %%
imgs = os.listdir("/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only2")

# %%
print(imgs)
# Out:
# ['700942Sample.png']

# %%
img = skio.imread("/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only2/700942Sample.png")
msk = skio.imread("/DataMount/chMouse/Mouse 2023 Pathology/NecroticTopology/image_only_output2/msk/700942Sample.png")

# %%
img.shape
# Out:
# (1742, 1547, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(msk)

# %%
msk.shape
# Out:
# (174, 155, 3)
